# %% [markdown]
# # Lab : Image Classification using Convolutional Neural Networks
#
# At the end of this laboratory, you would get familiarized with
#
# *   Creating deep networks using Keras
# *   Steps necessary in training a neural network
# *   Prediction and performance analysis using neural networks
#
# ---

# %% [markdown]
# # **In case you use a colaboratory environment**
# By default, Colab notebooks run on CPU.
# You can switch your notebook to run with GPU.
#
# In order to obtain access to the GPU, you need to choose the tab Runtime and then select “Change runtime type” as shown in the following figure:
#
# ![Changing runtime](https://miro.medium.com/max/747/1*euE7nGZ0uJQcgvkpgvkoQg.png)
#
# When a pop-up window appears select GPU. Ensure “Hardware accelerator” is set to GPU.

# %% [markdown]
# # **Working with a new dataset: CIFAR-10**
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images. More information about CIFAR-10 can be found [here](https://www.cs.toronto.edu/~kriz/cifar.html).
#
# In Keras, the CIFAR-10 dataset is also preloaded in the form of four Numpy arrays. x_train and y_train contain the training set, while x_test and y_test contain the test data. The images are encoded as Numpy arrays and their corresponding labels ranging from 0 to 9.
#
# Your task is to:
#
# *   Visualize the images in CIFAR-10 dataset. Create a 10 x 10 plot showing 10 random samples from each class.
# *   Convert the labels to one-hot encoded form.
# *   Normalize the images.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
# Your code here :
# VISUALIZE DATA

import matplotlib.pyplot as plt

# Get class labels
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Create a 10x10 plot
fig, axes = plt.subplots(10, 10, figsize=(12, 12))

for i in range(10):  # Iterate through each class
    # Get indices for the current class
    class_indices = np.where(y_train == i)[0]
    # Randomly sample 10 indices from the current class
    random_indices = np.random.choice(class_indices, 10, replace=False)

    for j, idx in enumerate(random_indices):
        axes[i, j].imshow(x_train[idx])
        axes[i, j].axis('off')  # Turn off axes
        if j == 0: # Add class name as title to the first image of each row
            axes[i, j].set_title(class_names[i])

plt.tight_layout()
plt.show()

# %%
# PREPARING LABELS CONVERT THE LABELS TO ONE-HOT ENCODED FORM

from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

print(y_train.shape)
print(y_test.shape)
# Out:
# (50000, 10)
# (10000, 10)

# %%
# NORMALIZE THE IMAGES
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

print(x_train.shape)
print(x_test.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %% [markdown]
# ## Define the following model (same as the one in tutorial)
#
# For the convolutional front-end, start with a single convolutional layer with a small filter size (3,3) and a modest number of filters (32) followed by a max pooling layer.
#
# Use the input as (32,32,3).
#
# The filter maps can then be flattened to provide features to the classifier.
#
# Use a dense layer with 100 units before the classification layer (which is also a dense layer with softmax activation).

# %%
#from keras.backend import clear_session
#clear_session()

# %%
# Your code here :
# Model / data parameters
num_classes = 10
input_shape = (32, 32, 3)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import BatchNormalization, Dropout
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, LearningRateScheduler

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        #layers.BatchNormalization(),
        #layers.Dropout(0.3), #adding dropout rate
        #layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        #layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2, 2)),

        layers.Conv2D(100, kernel_size=(3, 3), activation="relu"),
        #layers.BatchNormalization(),
        #layers.Dropout(0.3), #adding dropout rate
        #Layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        #layers.BatchNormalization(),
        #layers.MaxPooling2D(pool_size=(2, 2)),
        #layers.Dropout(0.3), #adding dropout rate
        #layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        #layers.BatchNormalization(),
        layers.Flatten(),
        #layers.Dropout(0.3),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_11 (Conv2D)              │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 13, 13, 100)    │        28,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 16900)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │       169,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 198,806 (776.59 KB)
#  Trainable params: 198,806 (776.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# *   Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric.
# *   Use the above defined model to train CIFAR-10 and train the model for 50 epochs with a batch size of 512.

# %%
# Your code here :
opt = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9)

model.compile(
    optimizer=opt,
    loss="categorical_crossentropy",
    metrics=["accuracy"])


history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    epochs=50,
    batch_size=64,
    verbose=1
)
# Out:
# Epoch 1/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.2356 - loss: 2.1201 - val_accuracy: 0.3533 - val_loss: 1.8469
# Epoch 2/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3842 - loss: 1.7702 - val_accuracy: 0.4405 - val_loss: 1.5915
# Epoch 3/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4495 - loss: 1.5726 - val_accuracy: 0.4690 - val_loss: 1.4933
# Epoch 4/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4891 - loss: 1.4387 - val_accuracy: 0.5126 - val_loss: 1.3832
# Epoch 5/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5258 - loss: 1.3583 - val_accuracy: 0.5334 - val_loss: 1.3166
# Epoch 6/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5482 - loss: 1.2937 - val_accuracy: 0.5473 - val_loss: 1.2819
# Epoch 7/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5678 - loss: 1.2339 - val_accuracy: 0.5563 - val_loss: 1.2520
# Epoch 8/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.5825 - loss: 1.1999 - val_accuracy: 0.5812 - val_loss: 1.2004
# Epoch 9/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5981 - loss: 1.1526 - val_accuracy: 0.5816 - val_loss: 1.1847
# Epoch 10/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6085 - loss: 1.1316 - val_accuracy: 0.6086 - val_loss: 1.1315
# Epoch 11/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.6231 - loss: 1.0920 - val_accuracy: 0.6101 - val_loss: 1.1156
# Epoch 12/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.6323 - loss: 1.0604 - val_accuracy: 0.6104 - val_loss: 1.1090
# Epoch 13/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6428 - loss: 1.0392 - val_accuracy: 0.6267 - val_loss: 1.0702
# Epoch 14/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6573 - loss: 1.0015 - val_accuracy: 0.6291 - val_loss: 1.0723
# Epoch 15/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6630 - loss: 0.9755 - val_accuracy: 0.6266 - val_loss: 1.0690
# Epoch 16/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6727 - loss: 0.9437 - val_accuracy: 0.6373 - val_loss: 1.0404
# Epoch 17/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6811 - loss: 0.9301 - val_accuracy: 0.6442 - val_loss: 1.0318
# Epoch 18/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.6905 - loss: 0.9049 - val_accuracy: 0.6402 - val_loss: 1.0312
# Epoch 19/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7033 - loss: 0.8762 - val_accuracy: 0.6497 - val_loss: 1.0021
# Epoch 20/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7073 - loss: 0.8590 - val_accuracy: 0.6581 - val_loss: 0.9854
# Epoch 21/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7102 - loss: 0.8411 - val_accuracy: 0.6671 - val_loss: 0.9655
# Epoch 22/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7186 - loss: 0.8328 - val_accuracy: 0.6657 - val_loss: 0.9707
# Epoch 23/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7280 - loss: 0.8017 - val_accuracy: 0.6652 - val_loss: 0.9719
# Epoch 24/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7276 - loss: 0.8012 - val_accuracy: 0.6706 - val_loss: 0.9530
# Epoch 25/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7372 - loss: 0.7698 - val_accuracy: 0.6705 - val_loss: 0.9651
# Epoch 26/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7409 - loss: 0.7699 - val_accuracy: 0.6722 - val_loss: 0.9559
# Epoch 27/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7492 - loss: 0.7415 - val_accuracy: 0.6790 - val_loss: 0.9481
# Epoch 28/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7499 - loss: 0.7371 - val_accuracy: 0.6786 - val_loss: 0.9409
# Epoch 29/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7613 - loss: 0.7118 - val_accuracy: 0.6784 - val_loss: 0.9524
# Epoch 30/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7655 - loss: 0.6982 - val_accuracy: 0.6687 - val_loss: 0.9778
# Epoch 31/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7674 - loss: 0.6849 - val_accuracy: 0.6833 - val_loss: 0.9309
# Epoch 32/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7741 - loss: 0.6724 - val_accuracy: 0.6725 - val_loss: 0.9731
# Epoch 33/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7806 - loss: 0.6527 - val_accuracy: 0.6714 - val_loss: 0.9810
# Epoch 34/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7800 - loss: 0.6414 - val_accuracy: 0.6863 - val_loss: 0.9349
# Epoch 35/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7909 - loss: 0.6213 - val_accuracy: 0.6794 - val_loss: 0.9613
# Epoch 36/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7921 - loss: 0.6138 - val_accuracy: 0.6862 - val_loss: 0.9451
# Epoch 37/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8006 - loss: 0.5965 - val_accuracy: 0.6840 - val_loss: 0.9374
# Epoch 38/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8078 - loss: 0.5740 - val_accuracy: 0.6811 - val_loss: 0.9438
# Epoch 39/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8098 - loss: 0.5717 - val_accuracy: 0.6911 - val_loss: 0.9337
# Epoch 40/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8125 - loss: 0.5554 - val_accuracy: 0.6845 - val_loss: 0.9552
# Epoch 41/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8213 - loss: 0.5394 - val_accuracy: 0.6904 - val_loss: 0.9539
# Epoch 42/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8242 - loss: 0.5308 - val_accuracy: 0.6668 - val_loss: 0.9981
# Epoch 43/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8219 - loss: 0.5263 - val_accuracy: 0.6882 - val_loss: 0.9599
# Epoch 44/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8343 - loss: 0.5031 - val_accuracy: 0.6780 - val_loss: 1.0037
# Epoch 45/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8385 - loss: 0.4927 - val_accuracy: 0.6829 - val_loss: 0.9708
# Epoch 46/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8430 - loss: 0.4822 - val_accuracy: 0.6798 - val_loss: 0.9994
# Epoch 47/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8444 - loss: 0.4718 - val_accuracy: 0.6848 - val_loss: 0.9961
# Epoch 48/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8495 - loss: 0.4570 - val_accuracy: 0.6818 - val_loss: 1.0038
# Epoch 49/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8536 - loss: 0.4436 - val_accuracy: 0.6804 - val_loss: 1.0168
# Epoch 50/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8599 - loss: 0.4258 - val_accuracy: 0.6794 - val_loss: 1.0190

# %% [markdown]
# *   Plot the cross entropy loss curve and the accuracy curve

# %%
# Your code here :
#Plot the cross entropy loss curve and the accuracy curve

loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
epochs = range(1, len(loss) + 1)

plt.figure(figsize=(12, 5))

# Plot Loss
plt.subplot(1, 2, 1)
plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Cross-Entropy Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, accuracy, label='Training Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Defining Deeper Architectures: VGG Models
#
# *   Define a deeper model architecture for CIFAR-10 dataset and train the new model for 50 epochs with a batch size of 512. We will use VGG model as the architecture.
#
# Stack two convolutional layers with 32 filters, each of 3 x 3.
#
# Use a max pooling layer and next flatten the output of the previous layer and add a dense layer with 128 units before the classification layer.
#
# For all the layers, use ReLU activation function.
#
# Use same padding for the layers to ensure that the height and width of each layer output matches the input

# %%
from keras.backend import clear_session
clear_session()

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import BatchNormalization, Dropout
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, LearningRateScheduler

# %%
num_classes = 10
input_shape = (32, 32, 3)

# %%
# Your code here :
modelVGG = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same'),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dense(128, activation="relu"),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

modelVGG.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,048,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,060,138 (4.04 MB)
#  Trainable params: 1,060,138 (4.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# *   Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric.
# *   Use the above defined model to train CIFAR-10 and train the model for 50 epochs with a batch size of 512.

# %%
# Your code here :
opt = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9)

modelVGG.compile(
    optimizer=opt,
    loss="categorical_crossentropy",
    metrics=["accuracy"])


history_vgg = modelVGG.fit( # Changed variable name to history_vgg
    x_train, y_train,
    validation_data=(x_test, y_test),
    epochs=50,
    batch_size=512,
    verbose=1
)
# Out:
# Epoch 1/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.1298 - loss: 2.2894 - val_accuracy: 0.2211 - val_loss: 2.2134
# Epoch 2/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.2354 - loss: 2.1685 - val_accuracy: 0.2915 - val_loss: 2.0355
# Epoch 3/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.2998 - loss: 1.9978 - val_accuracy: 0.3436 - val_loss: 1.9074
# Epoch 4/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.3407 - loss: 1.8895 - val_accuracy: 0.3565 - val_loss: 1.8527
# Epoch 5/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.3541 - loss: 1.8468 - val_accuracy: 0.3672 - val_loss: 1.8150
# Epoch 6/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.3666 - loss: 1.8155 - val_accuracy: 0.3757 - val_loss: 1.7817
# Epoch 7/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.3824 - loss: 1.7749 - val_accuracy: 0.3893 - val_loss: 1.7460
# Epoch 8/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.3980 - loss: 1.7376 - val_accuracy: 0.4055 - val_loss: 1.7153
# Epoch 9/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.4119 - loss: 1.7037 - val_accuracy: 0.4073 - val_loss: 1.6902
# Epoch 10/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.4128 - loss: 1.6843 - val_accuracy: 0.4150 - val_loss: 1.6551
# Epoch 11/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.4300 - loss: 1.6460 - val_accuracy: 0.4232 - val_loss: 1.6343
# Epoch 12/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.4304 - loss: 1.6297 - val_accuracy: 0.4355 - val_loss: 1.5984
# Epoch 13/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.4419 - loss: 1.5939 - val_accuracy: 0.4457 - val_loss: 1.5742
# Epoch 14/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.4535 - loss: 1.5719 - val_accuracy: 0.4437 - val_loss: 1.5655
# Epoch 15/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.4534 - loss: 1.5599 - val_accuracy: 0.4544 - val_loss: 1.5419
# Epoch 16/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.4684 - loss: 1.5311 - val_accuracy: 0.4582 - val_loss: 1.5268
# Epoch 17/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.4701 - loss: 1.5122 - val_accuracy: 0.4625 - val_loss: 1.5097
# Epoch 18/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.4751 - loss: 1.5014 - val_accuracy: 0.4739 - val_loss: 1.4945
# Epoch 19/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.4822 - loss: 1.4805 - val_accuracy: 0.4724 - val_loss: 1.4904
# Epoch 20/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.4859 - loss: 1.4639 - val_accuracy: 0.4800 - val_loss: 1.4662
# Epoch 21/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.4874 - loss: 1.4582 - val_accuracy: 0.4780 - val_loss: 1.4647
# Epoch 22/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.4952 - loss: 1.4287 - val_accuracy: 0.4856 - val_loss: 1.4394
# Epoch 23/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5011 - loss: 1.4216 - val_accuracy: 0.4887 - val_loss: 1.4386
# Epoch 24/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.5012 - loss: 1.4133 - val_accuracy: 0.5038 - val_loss: 1.4094
# Epoch 25/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.5146 - loss: 1.3856 - val_accuracy: 0.5013 - val_loss: 1.4026
# Epoch 26/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5170 - loss: 1.3776 - val_accuracy: 0.5100 - val_loss: 1.3822
# Epoch 27/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5214 - loss: 1.3612 - val_accuracy: 0.5098 - val_loss: 1.3769
# Epoch 28/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5281 - loss: 1.3426 - val_accuracy: 0.5177 - val_loss: 1.3647
# Epoch 29/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5364 - loss: 1.3269 - val_accuracy: 0.5206 - val_loss: 1.3545
# Epoch 30/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5393 - loss: 1.3162 - val_accuracy: 0.5272 - val_loss: 1.3400
# Epoch 31/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5445 - loss: 1.2995 - val_accuracy: 0.5341 - val_loss: 1.3124
# Epoch 32/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5515 - loss: 1.2821 - val_accuracy: 0.5342 - val_loss: 1.3088
# Epoch 33/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5548 - loss: 1.2711 - val_accuracy: 0.5402 - val_loss: 1.2936
# Epoch 34/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5600 - loss: 1.2584 - val_accuracy: 0.5375 - val_loss: 1.3035
# Epoch 35/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5657 - loss: 1.2394 - val_accuracy: 0.5373 - val_loss: 1.3003
# Epoch 36/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5691 - loss: 1.2375 - val_accuracy: 0.5536 - val_loss: 1.2546
# Epoch 37/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.5791 - loss: 1.2089 - val_accuracy: 0.5550 - val_loss: 1.2646
# Epoch 38/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.5738 - loss: 1.2142 - val_accuracy: 0.5569 - val_loss: 1.2511
# Epoch 39/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5824 - loss: 1.1914 - val_accuracy: 0.5597 - val_loss: 1.2342
# Epoch 40/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5827 - loss: 1.1907 - val_accuracy: 0.5630 - val_loss: 1.2293
# Epoch 41/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5917 - loss: 1.1724 - val_accuracy: 0.5647 - val_loss: 1.2175
# Epoch 42/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5969 - loss: 1.1580 - val_accuracy: 0.5762 - val_loss: 1.2049
# Epoch 43/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.5972 - loss: 1.1506 - val_accuracy: 0.5691 - val_loss: 1.2079
# Epoch 44/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6025 - loss: 1.1369 - val_accuracy: 0.5759 - val_loss: 1.1973
# Epoch 45/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6079 - loss: 1.1230 - val_accuracy: 0.5739 - val_loss: 1.1968
# Epoch 46/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6105 - loss: 1.1136 - val_accuracy: 0.5765 - val_loss: 1.1999
# Epoch 47/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6093 - loss: 1.1167 - val_accuracy: 0.5746 - val_loss: 1.2002
# Epoch 48/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6157 - loss: 1.1001 - val_accuracy: 0.5738 - val_loss: 1.2009
# Epoch 49/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6171 - loss: 1.0928 - val_accuracy: 0.5841 - val_loss: 1.1641
# Epoch 50/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6252 - loss: 1.0820 - val_accuracy: 0.5895 - val_loss: 1.1575

# %% [markdown]
# *   Compare the performance of both the models by plotting the loss and accuracy curves of both the training steps. Does the deeper model perform better? Comment on the observation.

# %%
# Your code here :

# %% [markdown]
# **Comment on the observation**
#
# The overfitting has been solved, but the accuracy has dicreased
# ...

# %% [markdown]
# *   Use predict function to predict the output for the test split
# *   Plot the confusion matrix for the new model and comment on the class confusions.

# %%
# Your code here :
import numpy as np
predictions = model.predict(x_test)

print(predictions.shape)
predictions = np.argmax(predictions, axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# (10000, 10)

# %%
predictions = modelVGG.predict(x_test)
print(predictions.shape)
predictions = np.argmax(predictions, axis=1)
gt = np.argmax(y_test, axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# (10000, 10)

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
confusion_matrix(gt, predictions)
# Out:
# array([[680,  31,  43,  32,  21,  10,  17,  14,  82,  70],
#        [ 30, 689,   9,  17,   3,   6,  13,   8,  34, 191],
#        [ 90,  12, 430,  78, 117,  89,  93,  52,  14,  25],
#        [ 25,  15,  62, 449,  61, 180,  92,  60,  14,  42],
#        [ 43,   9, 123,  84, 441,  49, 115, 107,  12,  17],
#        [ 17,   6,  64, 219,  58, 492,  46,  64,   9,  25],
#        [  4,  16,  64,  84,  55,  32, 689,  21,   9,  26],
#        [ 17,   7,  30,  75,  54,  80,  19, 660,   6,  52],
#        [119,  77,  13,  28,  12,  12,   6,   6, 665,  62],
#        [ 37, 137,  13,  26,   7,  15,  13,  27,  25, 700]])

# %% [markdown]
# **Comment here :**
#
# *(Double-click or enter to edit)*
#
# ...

# %% [markdown]
# *    Print the test accuracy for the trained model.

# %%
# Your code here :
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6848 - loss: 1.0170
# Test loss: 1.0190420150756836
# Test accuracy: 0.6794000267982483

# %%
test_loss, test_acc = modelVGG.evaluate(x_test, y_test)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5905 - loss: 1.1489
# Test loss: 1.1575230360031128
# Test accuracy: 0.5895000100135803

# %% [markdown]
# ## Define the complete VGG architecture.
#
# Stack two convolutional layers with 64 filters, each of 3 x 3 followed by max pooling layer.
#
# Stack two more convolutional layers with 128 filters, each of 3 x 3, followed by max pooling, followed by two more convolutional layers with 256 filters, each of 3 x 3, followed by max pooling.
#
# Flatten the output of the previous layer and add a dense layer with 128 units before the classification layer.
#
# For all the layers, use ReLU activation function.
#
# Use same padding for the layers to ensure that the height and width of each layer output matches the input
#
# *   Change the size of input to 64 x 64.

# %%
from keras.backend import clear_session
clear_session()

# %%
# Your code here :
modelVGG2 = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu", padding='same'),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu", padding='same'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(128, kernel_size=(3, 3), activation="relu", padding='same'),
        layers.Conv2D(128, kernel_size=(3, 3), activation="relu", padding='same'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(256, kernel_size=(3, 3), activation="relu", padding='same'),
        layers.Conv2D(256, kernel_size=(3, 3), activation="relu", padding='same'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dense(128, activation="relu"),
        layers.Dense(num_classes, activation="softmax"), # Removed padding='same'
    ]
)

modelVGG2.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │       524,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,671,114 (6.37 MB)
#  Trainable params: 1,671,114 (6.37 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# *   Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric.
# *   Use the above defined model to train CIFAR-10 and train the model for 10 epochs with a batch size of 512.
# *   Predict the output for the test split and plot the confusion matrix for the new model and comment on the class confusions.

# %% [markdown]
# # Understanding deep networks
#
# *   What is the use of activation functions in network? Why is it needed?
# *   We have used softmax activation function in the exercise. There are other activation functions available too. What is the difference between sigmoid activation and softmax activation?
# *   What is the difference between categorical crossentropy and binary crossentropy loss?

# %% [markdown]
# **Write the answers below :**
#
# 1 - Use of activation functions:
#
#
# Add non-linearity so the network can learn complex patterns.
#
# Without them, the model would just be linear (like simple regression).
#
#
#
# 2 - Key Differences between sigmoid and softmax:
#
#
# Sigmoid is used for binary classification and softmax for multiclass clasification.
#
#
# 3 - Key Differences between categorical crossentropy and binary crossentropy loss:
#
#
# Binary crossentropu los used in 2 classes probelm and with Sigmoid function and Categorical with multiple classes and softmax.
